# %% [markdown]
# # Linear and logistic regression
#
# This notebook completes the **Linear and logistic regression** assignment using the Real Estate Valuation dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/477/real+estate+valuation+data+set).
#
# The assignment consists of constructing two separate models for predicting the real estate prices in the dataset: one with linear and one with logistic regression.
#
# This assignments notebook includes sections for each of the six separate stages in the CRISP-DM model, with appropriate contents (including subsections for the two separate tasks in "Modeling" and "Evaluation").

# %% [markdown]
# ## 1. Business understanding

# %% [markdown]
# ## 2. Data understanding

# %% [markdown]
# ## 3. Data preparation

# %% [markdown]
# ## 4. Modeling

# %% [markdown]
# ### Linear regression model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("data/real_estate_valuation_dataset.csv")

X = df[["X1 transaction date"]]
y = df["Y house price of unit area"]

model = LinearRegression()
model.fit(X, y)

xs = np.linspace(X.min().iloc[0], X.max().iloc[0], 100).reshape(-1, 1) # small changes here
ys = model.predict(xs)

plt.scatter(X, y)
plt.plot(xs, ys)
plt.xlabel("Transaction date")
plt.ylabel("House price of unit area")
plt.show()
# Out:
# /home/kak3r/Documents/School/Datan käsittely ja koneoppiminen/machine-learning/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Logistic regression model

# %% [markdown]
# ## 5. Evaluation
#
# ### Linear regression model
#
# ### Logistic regression model

# %% [markdown]
# ## 6. Deployment
